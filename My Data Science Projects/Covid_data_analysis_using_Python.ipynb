# %% [markdown]
# # Covid data analysis using Python
# ## Checking the correlation between world happiness record and infection rate

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Dataset

# %%
covid_data=pd.read_csv("Data_covid.csv")
covid_data.head()
# Out:
#   Province/State Country/Region       Lat  ...  5/20/21  5/21/21  5/22/21
# 0            NaN    Afghanistan  33.93911  ...    64575    65080    65486
# 1            NaN        Albania  41.15330  ...   132118   132153   132176
# 2            NaN        Algeria  28.03390  ...   126156   126434   126651
# 3            NaN        Andorra  42.50630  ...    13569    13569    13569
# 4            NaN         Angola -11.20270  ...    31661    31909    32149
#
# [5 rows x 491 columns]

# %% [markdown]
# ### Deleting unwanted columns

# %%
covid_data.drop(["Lat","Long"],axis=1,inplace=True)

# %%
covid_data.head()
# Out:
#   Province/State Country/Region  1/22/20  ...  5/20/21  5/21/21  5/22/21
# 0            NaN    Afghanistan        0  ...    64575    65080    65486
# 1            NaN        Albania        0  ...   132118   132153   132176
# 2            NaN        Algeria        0  ...   126156   126434   126651
# 3            NaN        Andorra        0  ...    13569    13569    13569
# 4            NaN         Angola        0  ...    31661    31909    32149
#
# [5 rows x 489 columns]

# %% [markdown]
# ### Aggregating rows by countries

# %%
aggregated=covid_data.groupby("Country/Region").sum()
aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  5/20/21  5/21/21  5/22/21
# Country/Region                             ...
# Afghanistan           0        0        0  ...    64575    65080    65486
# Albania               0        0        0  ...   132118   132153   132176
# Algeria               0        0        0  ...   126156   126434   126651
# Andorra               0        0        0  ...    13569    13569    13569
# Angola                0        0        0  ...    31661    31909    32149
#
# [5 rows x 487 columns]

# %% [markdown]
#  ### Visualizing data related to a country

# %%
aggregated.loc["France"].plot()
aggregated.loc["Poland"].plot()
aggregated.loc["India"].plot()
plt.legend()

# %% [markdown]
# ### Finding the maximum infection rate for all countries

# %% [markdown]
# *The maximum infection rate represents the highest amount of new infections in a day*

# %%
countries=list(aggregated.index)
max_infection_rates=[]
for c in countries:
    max_infection_rates.append(aggregated.loc[c].diff().max())
aggregated["max_infection_rate"]=max_infection_rates

# %%
aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  5/21/21  5/22/21  max_infection_rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...    65080    65486              1485.0
# Albania               0        0        0  ...   132153   132176              1239.0
# Algeria               0        0        0  ...   126434   126651              1133.0
# Andorra               0        0        0  ...    13569    13569               299.0
# Angola                0        0        0  ...    31909    32149               393.0
#
# [5 rows x 488 columns]

# %% [markdown]
# Check out the last column !

# %%
max_infection=pd.DataFrame(aggregated["max_infection_rate"])

# %%
max_infection.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                 1485.0
# Albania                     1239.0
# Algeria                     1133.0
# Andorra                      299.0
# Angola                       393.0

# %% [markdown]
# ## Compare the infection rate with the world happiness record dataset

# %%
happy=pd.read_csv('WorldHappinessReport2019.csv')
happy.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Dropping the useless columns

# %%
useless_cols=["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
happy.drop(useless_cols,axis=1,inplace=True)
happy.set_index("Country or region",inplace=True)
happy.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %% [markdown]
# ### Merging the two datasets

# %%
data=max_infection.join(happy,how="inner")
data.head()
# Out:
#              max_infection_rate  ...  Freedom to make life choices
# Afghanistan              1485.0  ...                         0.000
# Albania                  1239.0  ...                         0.383
# Algeria                  1133.0  ...                         0.086
# Argentina               39652.0  ...                         0.471
# Armenia                  2476.0  ...                         0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Correlation matrix

# %% [markdown]
# *A correlation matrix shows correlation coefficients between variables*

# %%
data.corr()
# Out:
#                               max_infection_rate  ...  Freedom to make life choices
# max_infection_rate                      1.000000  ...                     -0.053286
# GDP per capita                          0.112200  ...                      0.394799
# Social support                          0.051395  ...                      0.456317
# Healthy life expectancy                 0.080984  ...                      0.423146
# Freedom to make life choices           -0.053286  ...                      1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Results

# %% [markdown]
# ### Plotting GDP vs maximum Infection rate

# %%
x=data["GDP per capita"]
y=data["max_infection_rate"]
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Plotting Social support vs maximum Infection rate

# %%
x=data["Social support"]
y=data["max_infection_rate"]
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Plotting Healthy life expectancy vs maximum Infection rate

# %%
x=data["Healthy life expectancy"]
y=data["max_infection_rate"]
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Plotting Freedom to make life choices vs maximum Infection rate

# %%
x=data["Freedom to make life choices"]
y=data["max_infection_rate"]
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
